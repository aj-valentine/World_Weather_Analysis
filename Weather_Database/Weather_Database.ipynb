# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time
# Get today's date in seconds.
today = time.time()

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=659027a178e99be814969635aa0bfe87

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 1 | pimentel
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | asfi
# Processing Record 8 of Set 1 | kidal
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | prince george
# Processing Record 11 of Set 1 | kaitangata
# Processing Record 12 of Set 1 | la baule-escoublac
# Processing Record 13 of Set 1 | vanimo
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | bals
# Processing Record 16 of Set 1 | aklavik
# Processing Record 17 of Set 1 | kirakira
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | mannarakkat
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | komsomolskiy
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | somerset
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | virginia beach
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | wegorzewo
# Processing Record 43 of Set 1 | senador jose porfirio
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | aioi
# Processing Record 46 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | rafaela
# Processing Record 49 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | itoman
# Processing Record 3 of Set 2 | mount isa
# Processing Record 4 of Set 2 | dombarovskiy
# Processing Record 5 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 2 | shingu
# Processing Record 7 of Set 2 | van wert
# Processing Record 8 of Set 2 | makakilo city
# Processing Record 9 of Set 2 | byron bay
# Processing Record 10 of Set 2 | luganville
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | warrnambool
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | yekaterinoslavka
# Processing Record 17 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | san julian
# Processing Record 20 of Set 2 | oarai
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | taksimo
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 2 | pernem
# Processing Record 31 of Set 2 | katangli
# Processing Record 32 of Set 2 | atbasar
# Processing Record 33 of Set 2 | ahipara
# Processing Record 34 of Set 2 | saint-pierre
# Processing Record 35 of Set 2 | madang
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | urumqi
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | beringovskiy
# Processing Record 40 of Set 2 | ojinaga
# Processing Record 41 of Set 2 | shaikhpura
# Processing Record 42 of Set 2 | tigre
# Processing Record 43 of Set 2 | panzhihua
# Processing Record 44 of Set 2 | nouadhibou
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | pangkalanbuun
# Processing Record 49 of Set 2 | coahuayana
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | pangnirtung
# Processing Record 3 of Set 3 | bambanglipuro
# Processing Record 4 of Set 3 | brownsville
# Processing Record 5 of Set 3 | linxia
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | puerto escondido
# Processing Record 9 of Set 3 | shenjiamen
# Processing Record 10 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 3 | pitimbu
# Processing Record 12 of Set 3 | mondlo
# Processing Record 13 of Set 3 | gilgit
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | margate
# Processing Record 16 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | xining
# Processing Record 19 of Set 3 | anadyr
# Processing Record 20 of Set 3 | narsaq
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | mehamn
# Processing Record 25 of Set 3 | dunedin
# Processing Record 26 of Set 3 | carndonagh
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | ucluelet
# Processing Record 29 of Set 3 | college
# Processing Record 30 of Set 3 | vardo
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | saint anthony
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | cortez
# Processing Record 36 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 3 | rawson
# Processing Record 38 of Set 3 | praia da vitoria
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | itarema
# Processing Record 41 of Set 3 | concarneau
# Processing Record 42 of Set 3 | varzea grande
# Processing Record 43 of Set 3 | san luis
# Processing Record 44 of Set 3 | kytlym
# City not found. Skipping...
# Processing Record 45 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 3 | san andres
# Processing Record 47 of Set 3 | verkhnyaya inta
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | havoysund
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | naze
# Processing Record 2 of Set 4 | katsuura
# Processing Record 3 of Set 4 | bilma
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | namibe
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | ambilobe
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | henties bay
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | erzin
# Processing Record 12 of Set 4 | naryan-mar
# Processing Record 13 of Set 4 | constitucion
# Processing Record 14 of Set 4 | meiganga
# Processing Record 15 of Set 4 | tuatapere
# Processing Record 16 of Set 4 | jumla
# Processing Record 17 of Set 4 | ouango
# Processing Record 18 of Set 4 | kamaishi
# Processing Record 19 of Set 4 | salinas
# Processing Record 20 of Set 4 | izvoarele sucevei
# Processing Record 21 of Set 4 | avera
# Processing Record 22 of Set 4 | sampit
# Processing Record 23 of Set 4 | sur
# Processing Record 24 of Set 4 | chicama
# Processing Record 25 of Set 4 | vung tau
# Processing Record 26 of Set 4 | campbellton
# Processing Record 27 of Set 4 | lorengau
# Processing Record 28 of Set 4 | shimoda
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | mahibadhoo
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | tabou
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | shache
# Processing Record 35 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 4 | rorvik
# Processing Record 37 of Set 4 | nhulunbuy
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | prachuap khiri khan
# Processing Record 40 of Set 4 | arraial do cabo
# Processing Record 41 of Set 4 | tutoia
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | provideniya
# Processing Record 44 of Set 4 | inndyr
# Processing Record 45 of Set 4 | awjilah
# Processing Record 46 of Set 4 | garmsar
# Processing Record 47 of Set 4 | callaway
# Processing Record 48 of Set 4 | agen
# Processing Record 49 of Set 4 | yudong
# Processing Record 50 of Set 4 | puerto ayacucho
# Processing Record 1 of Set 5 | saint-philippe
# Processing Record 2 of Set 5 | hami
# Processing Record 3 of Set 5 | lalibela
# Processing Record 4 of Set 5 | altay
# Processing Record 5 of Set 5 | birao
# Processing Record 6 of Set 5 | kindu
# Processing Record 7 of Set 5 | boa vista
# Processing Record 8 of Set 5 | chapais
# Processing Record 9 of Set 5 | radcliff
# Processing Record 10 of Set 5 | sechelt
# Processing Record 11 of Set 5 | georgetown
# Processing Record 12 of Set 5 | port hardy
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | carnot
# Processing Record 15 of Set 5 | leningradskiy
# Processing Record 16 of Set 5 | saint-augustin
# Processing Record 17 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 5 | abu samrah
# Processing Record 19 of Set 5 | sonari
# Processing Record 20 of Set 5 | liverpool
# Processing Record 21 of Set 5 | pyay
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | malanville
# Processing Record 25 of Set 5 | meulaboh
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | grindavik
# Processing Record 28 of Set 5 | york
# Processing Record 29 of Set 5 | kozhva
# Processing Record 30 of Set 5 | liuzhou
# Processing Record 31 of Set 5 | niteroi
# Processing Record 32 of Set 5 | senneterre
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | khani
# Processing Record 35 of Set 5 | kalmunai
# Processing Record 36 of Set 5 | juneau
# Processing Record 37 of Set 5 | mutata
# Processing Record 38 of Set 5 | vila velha
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | cabedelo
# Processing Record 41 of Set 5 | tomakomai
# Processing Record 42 of Set 5 | calbuco
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | north bend
# Processing Record 45 of Set 5 | aswan
# Processing Record 46 of Set 5 | kerman
# Processing Record 47 of Set 5 | cairns
# Processing Record 48 of Set 5 | okha
# Processing Record 49 of Set 5 | maciuca
# City not found. Skipping...
# Processing Record 50 of Set 5 | samarai
# Processing Record 1 of Set 6 | beloha
# Processing Record 2 of Set 6 | santa isabel do rio negro
# Processing Record 3 of Set 6 | ancud
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | luderitz
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 6 | bana
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | kodiak
# Processing Record 11 of Set 6 | chumikan
# Processing Record 12 of Set 6 | kihei
# Processing Record 13 of Set 6 | hay river
# Processing Record 14 of Set 6 | neiafu
# Processing Record 15 of Set 6 | kawardha
# Processing Record 16 of Set 6 | airai
# Processing Record 17 of Set 6 | linqiong
# Processing Record 18 of Set 6 | porto de moz
# Processing Record 19 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | carquefou
# Processing Record 21 of Set 6 | hastings
# Processing Record 22 of Set 6 | bethel
# Processing Record 23 of Set 6 | grand gaube
# Processing Record 24 of Set 6 | coihaique
# Processing Record 25 of Set 6 | monkey hill
# Processing Record 26 of Set 6 | puerto baquerizo moreno
# Processing Record 27 of Set 6 | avarua
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | kirkby
# Processing Record 30 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 6 | mount gambier
# Processing Record 33 of Set 6 | wanning
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | kasongo-lunda
# Processing Record 36 of Set 6 | muros
# Processing Record 37 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 38 of Set 6 | maryborough
# Processing Record 39 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 6 | dhidhdhoo
# Processing Record 41 of Set 6 | cayenne
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | flin flon
# Processing Record 44 of Set 6 | mareeba
# Processing Record 45 of Set 6 | sitka
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | ghatanji
# Processing Record 48 of Set 6 | cheremukhovo
# Processing Record 49 of Set 6 | russell
# Processing Record 50 of Set 6 | kalengwa
# Processing Record 1 of Set 7 | canon city
# Processing Record 2 of Set 7 | magdagachi
# Processing Record 3 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 7 | griffith
# Processing Record 5 of Set 7 | tuy hoa
# Processing Record 6 of Set 7 | jishou
# Processing Record 7 of Set 7 | sankheda
# Processing Record 8 of Set 7 | igarka
# Processing Record 9 of Set 7 | erenhot
# Processing Record 10 of Set 7 | kichmengskiy gorodok
# Processing Record 11 of Set 7 | nouakchott
# Processing Record 12 of Set 7 | husavik
# Processing Record 13 of Set 7 | svetlyy
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 7 | raudeberg
# Processing Record 17 of Set 7 | hong gai
# Processing Record 18 of Set 7 | pyinmana
# Processing Record 19 of Set 7 | domoni
# Processing Record 20 of Set 7 | emerald
# Processing Record 21 of Set 7 | ferrol
# Processing Record 22 of Set 7 | bahia honda
# Processing Record 23 of Set 7 | buala
# Processing Record 24 of Set 7 | nuuk
# Processing Record 25 of Set 7 | savannah bight
# Processing Record 26 of Set 7 | port hawkesbury
# Processing Record 27 of Set 7 | chifeng
# Processing Record 28 of Set 7 | ahuimanu
# Processing Record 29 of Set 7 | bonavista
# Processing Record 30 of Set 7 | magadi
# Processing Record 31 of Set 7 | codrington
# Processing Record 32 of Set 7 | batemans bay
# Processing Record 33 of Set 7 | panjakent
# Processing Record 34 of Set 7 | orangeville
# Processing Record 35 of Set 7 | arukutti
# Processing Record 36 of Set 7 | port augusta
# Processing Record 37 of Set 7 | goure
# Processing Record 38 of Set 7 | concepcion del oro
# Processing Record 39 of Set 7 | jacqueville
# Processing Record 40 of Set 7 | broome
# Processing Record 41 of Set 7 | praia
# Processing Record 42 of Set 7 | zabaykalsk
# Processing Record 43 of Set 7 | blythe
# Processing Record 44 of Set 7 | vila franca do campo
# Processing Record 45 of Set 7 | lagoa
# Processing Record 46 of Set 7 | vincennes
# Processing Record 47 of Set 7 | akhnur
# Processing Record 48 of Set 7 | lokosovo
# Processing Record 49 of Set 7 | tavira
# Processing Record 50 of Set 7 | muli
# Processing Record 1 of Set 8 | seymchan
# Processing Record 2 of Set 8 | riohacha
# Processing Record 3 of Set 8 | nome
# Processing Record 4 of Set 8 | khorramshahr
# Processing Record 5 of Set 8 | safford
# Processing Record 6 of Set 8 | loukhi
# Processing Record 7 of Set 8 | agadir
# Processing Record 8 of Set 8 | shirokiy
# Processing Record 9 of Set 8 | esperance
# Processing Record 10 of Set 8 | fortuna
# Processing Record 11 of Set 8 | sinnai
# Processing Record 12 of Set 8 | asau
# Processing Record 13 of Set 8 | azar shahr
# City not found. Skipping...
# Processing Record 14 of Set 8 | safonovo
# Processing Record 15 of Set 8 | tecoanapa
# Processing Record 16 of Set 8 | victoria
# Processing Record 17 of Set 8 | okhotsk
# Processing Record 18 of Set 8 | anloga
# Processing Record 19 of Set 8 | ayagoz
# Processing Record 20 of Set 8 | nongpoh
# Processing Record 21 of Set 8 | hayden
# Processing Record 22 of Set 8 | veere
# Processing Record 23 of Set 8 | salalah
# Processing Record 24 of Set 8 | zaozerne
# Processing Record 25 of Set 8 | oranjemund
# Processing Record 26 of Set 8 | shizunai
# Processing Record 27 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 28 of Set 8 | port lincoln
# Processing Record 29 of Set 8 | nanortalik
# Processing Record 30 of Set 8 | brae
# Processing Record 31 of Set 8 | liyang
# Processing Record 32 of Set 8 | joniskis
# Processing Record 33 of Set 8 | lithgow
# Processing Record 34 of Set 8 | souillac
# Processing Record 35 of Set 8 | liepaja
# Processing Record 36 of Set 8 | hannibal
# Processing Record 37 of Set 8 | mutare
# Processing Record 38 of Set 8 | tucupita
# Processing Record 39 of Set 8 | san juan
# Processing Record 40 of Set 8 | los llanos de aridane
# Processing Record 41 of Set 8 | torbay
# Processing Record 42 of Set 8 | the valley
# Processing Record 43 of Set 8 | odweyne
# Processing Record 44 of Set 8 | zambezi
# Processing Record 45 of Set 8 | san isidro
# Processing Record 46 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | acton
# Processing Record 48 of Set 8 | ternate
# Processing Record 49 of Set 8 | imeni poliny osipenko
# Processing Record 50 of Set 8 | kabompo
# Processing Record 1 of Set 9 | la ronge
# Processing Record 2 of Set 9 | sarai naurang
# Processing Record 3 of Set 9 | strezhevoy
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | sisimiut
# Processing Record 6 of Set 9 | srednekolymsk
# Processing Record 7 of Set 9 | sinnamary
# Processing Record 8 of Set 9 | oyotun
# Processing Record 9 of Set 9 | deputatskiy
# Processing Record 10 of Set 9 | verkh-usugli
# Processing Record 11 of Set 9 | fot
# Processing Record 12 of Set 9 | road town
# Processing Record 13 of Set 9 | sangre grande
# Processing Record 14 of Set 9 | meadow lake
# Processing Record 15 of Set 9 | balabac
# Processing Record 16 of Set 9 | darovskoy
# Processing Record 17 of Set 9 | lasa
# Processing Record 18 of Set 9 | barabai
# Processing Record 19 of Set 9 | tupiza
# Processing Record 20 of Set 9 | akim swedru
# Processing Record 21 of Set 9 | padang
# Processing Record 22 of Set 9 | poronaysk
# Processing Record 23 of Set 9 | cherskiy
# Processing Record 24 of Set 9 | chibombo
# Processing Record 25 of Set 9 | george enescu
# Processing Record 26 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 27 of Set 9 | olovyannaya
# Processing Record 28 of Set 9 | yoichi
# Processing Record 29 of Set 9 | camacha
# Processing Record 30 of Set 9 | pirajui
# Processing Record 31 of Set 9 | qaqortoq
# Processing Record 32 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 9 | cloquet
# Processing Record 34 of Set 9 | whitehorse
# Processing Record 35 of Set 9 | la paz
# Processing Record 36 of Set 9 | perehonivka
# Processing Record 37 of Set 9 | cejkovice
# Processing Record 38 of Set 9 | tadine
# Processing Record 39 of Set 9 | cravo norte
# Processing Record 40 of Set 9 | bakel
# Processing Record 41 of Set 9 | kavieng
# Processing Record 42 of Set 9 | mezhdurechensk
# Processing Record 43 of Set 9 | chernyshevskiy
# Processing Record 44 of Set 9 | jardim
# Processing Record 45 of Set 9 | taoudenni
# Processing Record 46 of Set 9 | zenzeli
# Processing Record 47 of Set 9 | menongue
# Processing Record 48 of Set 9 | sundargarh
# Processing Record 49 of Set 9 | havelock
# Processing Record 50 of Set 9 | alirajpur
# Processing Record 1 of Set 10 | magallanes
# Processing Record 2 of Set 10 | port macquarie
# Processing Record 3 of Set 10 | bosaso
# Processing Record 4 of Set 10 | mayo
# Processing Record 5 of Set 10 | sao miguel do araguaia
# Processing Record 6 of Set 10 | tha chang
# Processing Record 7 of Set 10 | port-gentil
# Processing Record 8 of Set 10 | polunochnoye
# Processing Record 9 of Set 10 | henderson
# Processing Record 10 of Set 10 | evensk
# Processing Record 11 of Set 10 | choix
# Processing Record 12 of Set 10 | toumba
# City not found. Skipping...
# Processing Record 13 of Set 10 | burica
# City not found. Skipping...
# Processing Record 14 of Set 10 | sergeyevka
# Processing Record 15 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 10 | gunjur
# Processing Record 17 of Set 10 | mackay
# Processing Record 18 of Set 10 | kieta
# Processing Record 19 of Set 10 | sao joao da barra
# Processing Record 20 of Set 10 | shrewsbury
# Processing Record 21 of Set 10 | puri
# Processing Record 22 of Set 10 | vanino
# Processing Record 23 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 24 of Set 10 | dhuburi
# Processing Record 25 of Set 10 | poum
# Processing Record 26 of Set 10 | nueve de julio
# Processing Record 27 of Set 10 | banjar
# Processing Record 28 of Set 10 | tukrah
# Processing Record 29 of Set 10 | gornyak
# Processing Record 30 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 10 | abbeville
# Processing Record 32 of Set 10 | isangel
# Processing Record 33 of Set 10 | actopan
# Processing Record 34 of Set 10 | isiro
# Processing Record 35 of Set 10 | tenkodogo
# Processing Record 36 of Set 10 | williams lake
# Processing Record 37 of Set 10 | carutapera
# Processing Record 38 of Set 10 | kristiansund
# Processing Record 39 of Set 10 | paamiut
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | porto novo
# Processing Record 42 of Set 10 | vangaindrano
# Processing Record 43 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 10 | sola
# Processing Record 45 of Set 10 | areia branca
# Processing Record 46 of Set 10 | cermik
# Processing Record 47 of Set 10 | san felipe
# Processing Record 48 of Set 10 | seoul
# Processing Record 49 of Set 10 | goderich
# Processing Record 50 of Set 10 | niamey
# Processing Record 1 of Set 11 | kharp
# Processing Record 2 of Set 11 | kano
# Processing Record 3 of Set 11 | tautira
# Processing Record 4 of Set 11 | zyryanka
# Processing Record 5 of Set 11 | jatibonico
# Processing Record 6 of Set 11 | praya
# Processing Record 7 of Set 11 | akyab
# Processing Record 8 of Set 11 | koslan
# Processing Record 9 of Set 11 | walvis bay
# Processing Record 10 of Set 11 | lewistown
# Processing Record 11 of Set 11 | leh
# Processing Record 12 of Set 11 | las cruces
# Processing Record 13 of Set 11 | tezu
# Processing Record 14 of Set 11 | mokhsogollokh
# Processing Record 15 of Set 11 | acapulco
# Processing Record 16 of Set 11 | kununurra
# Processing Record 17 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 11 | chenzhou
# Processing Record 19 of Set 11 | ketchikan
# Processing Record 20 of Set 11 | lerwick
# Processing Record 21 of Set 11 | tevaitoa
# Processing Record 22 of Set 11 | clyde river
# Processing Record 23 of Set 11 | hualmay
# Processing Record 24 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 11 | longyan
# Processing Record 26 of Set 11 | sao felix do xingu
# Processing Record 27 of Set 11 | pangody
# Processing Record 28 of Set 11 | llangefni
# Processing Record 29 of Set 11 | rundu
# Processing Record 30 of Set 11 | talakan
# Processing Record 31 of Set 11 | rio grande
# Processing Record 32 of Set 11 | saint-georges
# Processing Record 33 of Set 11 | oksfjord
# Processing Record 34 of Set 11 | garissa
# Processing Record 35 of Set 11 | novoagansk
# Processing Record 36 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 11 | champerico
# Processing Record 38 of Set 11 | novyy yarychiv
# Processing Record 39 of Set 11 | galle
# Processing Record 40 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 41 of Set 11 | burns lake
# Processing Record 42 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 11 | lukoyanov
# Processing Record 44 of Set 11 | fakel
# Processing Record 45 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 46 of Set 11 | caravelas
# Processing Record 47 of Set 11 | buraydah
# Processing Record 48 of Set 11 | moscow
# Processing Record 49 of Set 11 | santander
# Processing Record 50 of Set 11 | goundam
# Processing Record 1 of Set 12 | maisuru
# City not found. Skipping...
# Processing Record 2 of Set 12 | la union
# Processing Record 3 of Set 12 | cadillac
# Processing Record 4 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 12 | kautokeino
# Processing Record 6 of Set 12 | quballat
# Processing Record 7 of Set 12 | poso
# Processing Record 8 of Set 12 | san juan del sur
# Processing Record 9 of Set 12 | lachi
# Processing Record 10 of Set 12 | jinzhou
# Processing Record 11 of Set 12 | kolpashevo
# Processing Record 12 of Set 12 | key west
# Processing Record 13 of Set 12 | samba
# Processing Record 14 of Set 12 | magadan
# Processing Record 15 of Set 12 | asyut
# Processing Record 16 of Set 12 | mildura
# Processing Record 17 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 18 of Set 12 | batagay
# Processing Record 19 of Set 12 | sistranda
# Processing Record 20 of Set 12 | lucapa
# Processing Record 21 of Set 12 | zhengjiatun
# Processing Record 22 of Set 12 | nago
# Processing Record 23 of Set 12 | chaman
# Processing Record 24 of Set 12 | coquimbo
# Processing Record 25 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 12 | kosh-agach
# Processing Record 27 of Set 12 | alta floresta
# Processing Record 28 of Set 12 | stabroek
# Processing Record 29 of Set 12 | innisfail
# Processing Record 30 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 12 | bubaque
# Processing Record 32 of Set 12 | de-kastri
# Processing Record 33 of Set 12 | yunjinghong
# City not found. Skipping...
# Processing Record 34 of Set 12 | sumenep
# Processing Record 35 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 12 | verkhoyansk
# Processing Record 37 of Set 12 | faya
# Processing Record 38 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 12 | hobyo
# Processing Record 40 of Set 12 | roald
# Processing Record 41 of Set 12 | ruwi
# Processing Record 42 of Set 12 | mumford
# Processing Record 43 of Set 12 | hof
# Processing Record 44 of Set 12 | goma
# Processing Record 45 of Set 12 | matara
# Processing Record 46 of Set 12 | santa isabel
# Processing Record 47 of Set 12 | suntar
# Processing Record 48 of Set 12 | yining
# Processing Record 49 of Set 12 | carballo
# Processing Record 50 of Set 12 | berlevag
# Processing Record 1 of Set 13 | otane
# Processing Record 2 of Set 13 | solyanka
# Processing Record 3 of Set 13 | misratah
# Processing Record 4 of Set 13 | nelson bay
# Processing Record 5 of Set 13 | iquique
# Processing Record 6 of Set 13 | hopelchen
# Processing Record 7 of Set 13 | qandala
# Processing Record 8 of Set 13 | prenzlau
# Processing Record 9 of Set 13 | manokwari
# Processing Record 10 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 11 of Set 13 | te anau
# Processing Record 12 of Set 13 | abu dhabi
# Processing Record 13 of Set 13 | rypefjord
# Processing Record 14 of Set 13 | westport
# Processing Record 15 of Set 13 | klaksvik
# Processing Record 16 of Set 13 | maun
# Processing Record 17 of Set 13 | comodoro rivadavia
# Processing Record 18 of Set 13 | wang saphung
# Processing Record 19 of Set 13 | jundubah
# City not found. Skipping...
# Processing Record 20 of Set 13 | kokopo
# Processing Record 21 of Set 13 | kushima
# Processing Record 22 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | warsaw
# Processing Record 24 of Set 13 | necochea
# Processing Record 25 of Set 13 | acari
# Processing Record 26 of Set 13 | half moon bay
# Processing Record 27 of Set 13 | golden
# Processing Record 28 of Set 13 | antofagasta
# Processing Record 29 of Set 13 | korla
# Processing Record 30 of Set 13 | luena
# Processing Record 31 of Set 13 | kvitok
# Processing Record 32 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 33 of Set 13 | sechura
# Processing Record 34 of Set 13 | karachi
# Processing Record 35 of Set 13 | srandakan
# Processing Record 36 of Set 13 | markova
# Processing Record 37 of Set 13 | pochutla
# Processing Record 38 of Set 13 | buckeye
# Processing Record 39 of Set 13 | georgiyevka
# Processing Record 40 of Set 13 | bakhmach
# Processing Record 41 of Set 13 | mitsamiouli
# Processing Record 42 of Set 13 | makinsk
# Processing Record 43 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 44 of Set 13 | nishihara
# Processing Record 45 of Set 13 | hambantota
# Processing Record 46 of Set 13 | kaeo
# Processing Record 47 of Set 13 | vallenar
# Processing Record 48 of Set 13 | banff
# Processing Record 49 of Set 13 | micheweni
# Processing Record 50 of Set 13 | mouila
# Processing Record 1 of Set 14 | hemsedal
# Processing Record 2 of Set 14 | baiyin
# Processing Record 3 of Set 14 | hovd
# Processing Record 4 of Set 14 | yelets
# Processing Record 5 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 14 | inhambane
# Processing Record 7 of Set 14 | izhma
# Processing Record 8 of Set 14 | stettler
# Processing Record 9 of Set 14 | richards bay
# Processing Record 10 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 14 | tokat
# Processing Record 12 of Set 14 | talnakh
# Processing Record 13 of Set 14 | kanbe
# Processing Record 14 of Set 14 | kirovskaya
# Processing Record 15 of Set 14 | banamba
# Processing Record 16 of Set 14 | najran
# Processing Record 17 of Set 14 | malakal
# Processing Record 18 of Set 14 | tiarei
# Processing Record 19 of Set 14 | waipawa
# Processing Record 20 of Set 14 | belmonte
# Processing Record 21 of Set 14 | talcahuano
# Processing Record 22 of Set 14 | hirara
# Processing Record 23 of Set 14 | ocho rios
# Processing Record 24 of Set 14 | asekeyevo
# Processing Record 25 of Set 14 | tamiahua
# Processing Record 26 of Set 14 | indiana
# Processing Record 27 of Set 14 | hengyang
# Processing Record 28 of Set 14 | xuddur
# Processing Record 29 of Set 14 | palu
# Processing Record 30 of Set 14 | surgut
# Processing Record 31 of Set 14 | kuching
# Processing Record 32 of Set 14 | esterhazy
# Processing Record 33 of Set 14 | ust-nera
# Processing Record 34 of Set 14 | kuusamo
# Processing Record 35 of Set 14 | yakuplu
# Processing Record 36 of Set 14 | sendhwa
# Processing Record 37 of Set 14 | aksarka
# Processing Record 38 of Set 14 | kavaratti
# Processing Record 39 of Set 14 | san javier
# Processing Record 40 of Set 14 | kutum
# Processing Record 41 of Set 14 | burnie
# Processing Record 42 of Set 14 | dali
# Processing Record 43 of Set 14 | peniche
# Processing Record 44 of Set 14 | camopi
# Processing Record 45 of Set 14 | ola
# Processing Record 46 of Set 14 | bikin
# Processing Record 47 of Set 14 | netivot
# Processing Record 48 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 14 | dandong
# Processing Record 50 of Set 14 | biak
# Processing Record 1 of Set 15 | pencaitland
# Processing Record 2 of Set 15 | villaviciosa
# Processing Record 3 of Set 15 | nola
# Processing Record 4 of Set 15 | saint-joseph
# Processing Record 5 of Set 15 | norwalk
# Processing Record 6 of Set 15 | milyutinskaya
# Processing Record 7 of Set 15 | tierra colorada
# Processing Record 8 of Set 15 | barbate
# Processing Record 9 of Set 15 | sterling
# Processing Record 10 of Set 15 | auki
# Processing Record 11 of Set 15 | fairbanks
# Processing Record 12 of Set 15 | pringsewu
# Processing Record 13 of Set 15 | imbituba
# Processing Record 14 of Set 15 | pimenta bueno
# Processing Record 15 of Set 15 | sioux lookout
# Processing Record 16 of Set 15 | odessa
# Processing Record 17 of Set 15 | hope
# Processing Record 18 of Set 15 | tura
# Processing Record 19 of Set 15 | eyl
# Processing Record 20 of Set 15 | kuznechnoye
# Processing Record 21 of Set 15 | yumen
# Processing Record 22 of Set 15 | derzhavinsk
# Processing Record 23 of Set 15 | san rafael
# Processing Record 24 of Set 15 | isnos
# Processing Record 25 of Set 15 | fecamp
# Processing Record 26 of Set 15 | haines junction
# Processing Record 27 of Set 15 | kelvington
# Processing Record 28 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 29 of Set 15 | hanna
# Processing Record 30 of Set 15 | montrose
# Processing Record 31 of Set 15 | mpika
# Processing Record 32 of Set 15 | salta
# Processing Record 33 of Set 15 | klyuchi
# Processing Record 34 of Set 15 | aktas
# Processing Record 35 of Set 15 | geilo
# Processing Record 36 of Set 15 | sulmona
# Processing Record 37 of Set 15 | aquiraz
# Processing Record 38 of Set 15 | athabasca
# Processing Record 39 of Set 15 | dargaville
# Processing Record 40 of Set 15 | damietta
# Processing Record 41 of Set 15 | kuryk
# Processing Record 42 of Set 15 | tomatlan
# Processing Record 43 of Set 15 | kiruna
# Processing Record 44 of Set 15 | le port
# Processing Record 45 of Set 15 | bud
# Processing Record 46 of Set 15 | potosi
# Processing Record 47 of Set 15 | nirgua
# Processing Record 48 of Set 15 | milkovo
# Processing Record 49 of Set 15 | palana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Port Alfred -33.59   26.89     48.99        73           0
# 1            Pimentel  -6.84  -79.93     61.16        87          65
# 2              Hobart -42.88  147.33     48.20        49          40
# 3              Barrow  71.29 -156.79     39.20        86          90
# 4                Asfi  32.30   -9.24     69.31        72           0
# 5               Kidal  18.44    1.41     84.07        59          28
# 6         Yellowknife  62.46 -114.35     53.60        50          20
# 7       Prince George  53.92 -122.75     54.00        76          75
# 8          Kaitangata -46.28  169.85     61.05        48         100
# 9  La Baule-Escoublac  47.29   -2.36     53.01        93          99
#
#    Wind Speed Country                 Date
# 0       10.67      ZA  2020-08-31 01:22:26
# 1       14.36      PE  2020-08-31 01:22:27
# 2       14.99      AU  2020-08-31 01:18:52
# 3       16.11      US  2020-08-31 01:20:52
# 4       14.54      MA  2020-08-31 01:19:51
# 5        4.68      ML  2020-08-31 01:22:27
# 6       12.75      CA  2020-08-31 01:22:27
# 7        8.05      CA  2020-08-31 01:22:28
# 8       15.10      NZ  2020-08-31 01:22:28
# 9        3.36      FR  2020-08-31 01:22:28

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Port Alfred      ZA -33.59   26.89     48.99        73           0
# 1            Pimentel      PE  -6.84  -79.93     61.16        87          65
# 2              Hobart      AU -42.88  147.33     48.20        49          40
# 3              Barrow      US  71.29 -156.79     39.20        86          90
# 4                Asfi      MA  32.30   -9.24     69.31        72           0
# 5               Kidal      ML  18.44    1.41     84.07        59          28
# 6         Yellowknife      CA  62.46 -114.35     53.60        50          20
# 7       Prince George      CA  53.92 -122.75     54.00        76          75
# 8          Kaitangata      NZ -46.28  169.85     61.05        48         100
# 9  La Baule-Escoublac      FR  47.29   -2.36     53.01        93          99
#
#    Wind Speed
# 0       10.67
# 1       14.36
# 2       14.99
# 3       16.11
# 4       14.54
# 5        4.68
# 6       12.75
# 7        8.05
# 8       15.10
# 9        3.36

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
